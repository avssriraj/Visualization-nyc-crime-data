# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('NYC_crime.csv')

# %%
df
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0    749595529           34  MANHATTAN   01/01/2016     00:01:00   01/01/2018
# 1    134301299           25  MANHATTAN   01/01/2016     08:00:00   12/31/2017
# 2    813010521           13  MANHATTAN   01/01/2016     00:01:00   05/01/2019
# 3    314597003           30  MANHATTAN   01/01/2016     00:00:00   06/14/2021
# 4    253714310           20  MANHATTAN   01/01/2016     00:01:00   12/31/2019
# 5    193519890           32  MANHATTAN   01/01/2016     00:01:00   12/31/2016
# 6    540916634           17  MANHATTAN   01/02/2016     12:00:00   01/08/2017
# 7    514451869           13  MANHATTAN   02/08/2016     00:01:00   11/04/2020
# 8    870035835           33  MANHATTAN   02/24/2016     00:01:00   12/30/2019
# 9    370776797           28  MANHATTAN   03/01/2016     00:00:00   06/13/2021
# 10   407661851           30  MANHATTAN   03/01/2016     07:00:00   03/18/2021
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Latitude'], df['Longitude'])

# %%
data1 = df.iloc[:7,:]
data1
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   749595529           34  MANHATTAN   01/01/2016     00:01:00   01/01/2018
# 1   134301299           25  MANHATTAN   01/01/2016     08:00:00   12/31/2017
# 2   813010521           13  MANHATTAN   01/01/2016     00:01:00   05/01/2019
# 3   314597003           30  MANHATTAN   01/01/2016     00:00:00   06/14/2021
# 4   253714310           20  MANHATTAN   01/01/2016     00:01:00   12/31/2019
# 5   193519890           32  MANHATTAN   01/01/2016     00:01:00   12/31/2016
# 6   540916634           17  MANHATTAN   01/02/2016     12:00:00   01/08/2017
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD  HADEVELOPT           JURIS_DESC  ...  \
# 0     00:01:00        COMPLETED         NaN     N.Y. POLICE DEPT  ...
# 1     09:00:00        COMPLETED         NaN  N.Y. HOUSING POLICE  ...
# 2     23:59:00        COMPLETED         NaN     N.Y. POLICE DEPT  ...
# 3     19:22:00        COMPLETED         NaN     N.Y. POLICE DEPT  ...
# ...

# %%
data2 = df.iloc[7:9,:]
data2
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 7   514451869           13  MANHATTAN   02/08/2016     00:01:00   11/04/2020
# 8   870035835           33  MANHATTAN   02/24/2016     00:01:00   12/30/2019
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD  HADEVELOPT        JURIS_DESC  ...  PARKS_NM  \
# 7     23:59:00        COMPLETED         NaN  N.Y. POLICE DEPT  ...       NaN
# 8     23:59:00        COMPLETED         NaN  N.Y. POLICE DEPT  ...       NaN
#
#   PD_CD                         PD_DESC    PREM_TYP_DESC      RPT_DT  \
# 7   718  FRAUD,UNCLASSIFIED-MISDEMEANOR  PUBLIC BUILDING  03/16/2021
# 8   407  LARCENY,GRAND BY DISHONEST EMP            OTHER  02/16/2021
#
#    X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 7     988,699    208,577  40.739179 -73.983947
# 8   1,000,921    242,961  40.833540 -73.939758
#
#                                    Lat_Lon
# 7  (40.73917941600007, -73.98394690499998)
# 8  (40.83353970300004, -73.93975760199999)
#
# ...

# %%
data3 = df.iloc[9:12,:]
data3
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 9    370776797           28  MANHATTAN   03/01/2016     00:00:00   06/13/2021
# 10   407661851           30  MANHATTAN   03/01/2016     07:00:00   03/18/2021
# 11   351205390           26  MANHATTAN   03/27/2016     18:00:00   03/27/2016
#
#    CMPLNT_TO_TM CRM_ATPT_CPTD_CD  HADEVELOPT        JURIS_DESC  ...  PARKS_NM  \
# 9      00:00:00        COMPLETED         NaN  N.Y. POLICE DEPT  ...       NaN
# 10     16:00:00        COMPLETED         NaN  N.Y. POLICE DEPT  ...       NaN
# 11     19:00:00        COMPLETED         NaN  N.Y. POLICE DEPT  ...       NaN
#
#    PD_CD                                       PD_DESC  \
# 9    157                                        RAPE 1
# 10   422  LARCENY,GRAND BY OPEN CREDIT CARD (NEW ACCT)
# 11   638                         HARASSMENT,SUBD 3,4,5
#
#              PREM_TYP_DESC      RPT_DT  X_COORD_CD Y_COORD_CD   Latitude  \
# ...

# %%
mean_lat = df["Latitude"].mean()
mean_long = df["Longitude"].mean()

mean_lat1 = data1["Latitude"].mean()
mean_long1 = data1["Longitude"].mean()

mean_lat2 = data2["Latitude"].mean()
mean_long2 = data2["Longitude"].mean()

mean_lat3 = data3["Latitude"].mean()
mean_long3 = data3["Longitude"].mean()

# %%
print(mean_long1, mean_long2, mean_long3)
# Out:
# -73.95652140357139 -73.96185225349998 -73.95650752366663

# %%
print(mean_lat1, mean_lat2, mean_lat3)
# Out:
# 40.795918741571484 40.786359559500056 40.8145262983334

# %%
from shapely.geometry import LineString
import pandas as pd


j1 = {"x1": mean_lat1, "y1": mean_long1,
     "x2": data1["Latitude"], "y2": data1["Longitude"],}
dataf1 = pd.DataFrame(j1)

j2 = {"x1": mean_lat2, "y1": mean_long2,
     "x2": data2["Latitude"], "y2": data2["Longitude"],}
dataf2 = pd.DataFrame(j2)

j3 = {"x1": mean_lat3, "y1": mean_long3,
     "x2": data3["Latitude"], "y2": data3["Longitude"],}
dataf3 = pd.DataFrame(j3)

# %%
def get_distance_1(k):
  lstr = LineString([(k.x1, k.y1,), (k.x2, k.y2) ])
  return lstr.length

def get_diff_x_1(l):
    v = (l.x1 - l.x2)**2
    return v

def get_diff_y_1(m):
    u = (m.y1 - m.y2) ** 2
    return u

def get_distance_2(k):
  lstr = LineString([(k.x1, k.y1,), (k.x2, k.y2) ])
  return lstr.length

def get_diff_x_2(l):
    v = (l.x1 - l.x2)**2
    return v

def get_diff_y_2(m):
    u = (m.y1 - m.y2) ** 2
    return u

def get_distance_3(k):
  lstr = LineString([(k.x1, k.y1,), (k.x2, k.y2) ])
  return lstr.length

def get_diff_x_3(l):
    v = (l.x1 - l.x2)**2
    return v

def get_diff_y_3(m):
    u = (m.y1 - m.y2) ** 2
    return u

dataf1["Dist"] = dataf1.apply(get_distance_1, axis=1)
dataf1["diff_sq_x"] = dataf1.apply(get_diff_x_1, axis = 1)
dataf1["diff_sq_y"] = dataf1.apply(get_diff_y_1, axis = 1)

dataf2["Dist"] = dataf2.apply(get_distance_2, axis=1)
dataf2["diff_sq_x"] = dataf2.apply(get_diff_x_2, axis = 1)
dataf2["diff_sq_y"] = dataf2.apply(get_diff_y_2, axis = 1)

dataf3["Dist"] = dataf3.apply(get_distance_3, axis=1)
dataf3["diff_sq_x"] = dataf3.apply(get_diff_x_3, axis = 1)
dataf3["diff_sq_y"] = dataf3.apply(get_diff_y_3, axis = 1)

# %%
dataf1
# Out:
#           x1         y1         x2         y2      Dist  diff_sq_x  diff_sq_y
# 0  40.795919 -73.956521  40.851488 -73.935458  0.059427   0.003088   0.000444
# 1  40.795919 -73.956521  40.800694 -73.941109  0.016135   0.000023   0.000238
# 2  40.795919 -73.956521  40.736698 -73.983316  0.065000   0.003507   0.000718
# 3  40.795919 -73.956521  40.828851 -73.943834  0.035292   0.001085   0.000161
# 4  40.795919 -73.956521  40.783862 -73.975956  0.022870   0.000145   0.000378
# 5  40.795919 -73.956521  40.815732 -73.945420  0.022711   0.000393   0.000123
# 6  40.795919 -73.956521  40.754105 -73.970556  0.044106   0.001748   0.000197

# %%
dataf2
# Out:
#          x1         y1         x2         y2      Dist  diff_sq_x  diff_sq_y
# 7  40.78636 -73.961852  40.739179 -73.983947  0.052097   0.002226   0.000488
# 8  40.78636 -73.961852  40.833540 -73.939758  0.052097   0.002226   0.000488

# %%
dataf3
# Out:
#            x1         y1         x2         y2      Dist  diff_sq_x  \
# 9   40.814526 -73.956508  40.808750 -73.952586  0.006982   0.000033
# 10  40.814526 -73.956508  40.821967 -73.956424  0.007441   0.000055
# 11  40.814526 -73.956508  40.812862 -73.960512  0.004337   0.000003
#
#        diff_sq_y
# 9   1.537987e-05
# 10  6.926179e-09
# 11  1.603956e-05

# %%
math.sqrt((40.78636 - 40.739179)**2 + (-73.961852 + 73.983947)**2)
# Out:
# 0.052098328053791734

# %%
# Out:
# 0.02022000000000901

# %%
# Out:
# 0.0004088484000003643

# %%
# Out:
# 0.0009282325000003885

# %%
# Out:
# 0.030466908277677087

# %%
median1 = dataf1["Dist"].median()
median2 = dataf2["Dist"].median()
median3 = dataf3["Dist"].median()
print(median1, median2, median3)
# Out:
# 0.0352916700078905 0.052097404595484856 0.006981876606706879

# %%
avg_x1 = dataf1["diff_sq_x"].sum() / 7
avg_y1 = dataf1["diff_sq_y"].sum() / 7
sd1 = math.sqrt(avg_x1 + avg_y1)

avg_x2 = dataf2["diff_sq_x"].sum() / 2
avg_y2 = dataf2["diff_sq_y"].sum() / 2
sd2 = math.sqrt(avg_x2 + avg_y2)

avg_x3 = dataf3["diff_sq_x"].sum() / 3
avg_y3 = dataf3["diff_sq_y"].sum() / 3
sd3 = math.sqrt(avg_x3 + avg_y3)

# %%
print(sd1, sd2, sd3)
# Out:
# 0.041827264963506 0.052097404595484856 0.006401343479688125

# %%
# Out:
# 0.0022580209888460228 0.0009763472498127285 3.142635071944808e-05

# %%
avg_x = sum_x/12
avg_x
# Out:
# 0.0013034390877244156

# %%
avg_y = sum_y/12

# %%
avg_y
# Out:
# 0.00027610269023355577

# %%
avg_x + avg_y
# Out:
# 0.0015795417779579713

# %%
sd = math.sqrt(0.0015795417779579713)

# %%
sd
# Out:
# 0.03974344949747029

# %%
ln = math.sqrt(1/0.693147181)
ln
# Out:
# 1.2011224084051748

# %%
med1 = ln * median1
med2 = ln * median2
med3 = ln * median3
print(med1, med2, med3)
# Out:
# 0.04238961567651811 0.06257536007938759 0.008386088445035515

# %%
min_of1 = min(sd1, med1)
min_of2 = min(sd2, med2)
min_of3 = min(sd3, med3)
print(min_of1, min_of2, min_of3)
# Out:
# 0.041827264963506 0.052097404595484856 0.006401343479688125

# %%
# Out:
# 0.6083643418932058

# %%
term31 = math.pow(7, -0.2)
term32 = math.pow(2, -0.2)
term33 = math.pow(3, -0.2)
print(term31, term32, term33)
# Out:
# 0.677610913400481 0.8705505632961241 0.8027415617602307

# %%
search_radius1 = term31 * min_of1 * 0.9
search_radius2 = term32 * min_of2 * 0.9
search_radius3 = term33 * min_of3 * 0.9
print(search_radius1, search_radius2, search_radius3)
# Out:
# 0.025508350095268712 0.040818082425178884 0.0046247620160236634

# %%
rangeofx = dataf1["x2"].max() - dataf1["x2"].min()
rangeofx
# Out:
# 0.11478970400003163

# %%
rangeofy = dataf1["y2"].max() - dataf1["y2"].min()
rangeofy
# Out:
# 0.048488938000048165

# %%
pixel_x = 0.4/400
pixel_y = 0.4/400

# %%
pixel_x
# Out:
# 0.001

# %%
pixel_y
# Out:
# 0.001

# %%
p1 = 40.5
p2 = 40.9
p3 = -74.2
p4 = -73.8

# %%
print(p1,p2,p3,p4)
# Out:
# 40.5 40.9 -74.2 -73.8

# %%
y_arr = []
x_arr = []

while(p3 < p4 and p2 > p1):
    
    y_arr.append(p3 + pixel_y)
    x_arr.append(p2 - pixel_x)
    p3 = p3 + pixel_y
    p2 = p2 - pixel_x
    
x_arr, y_arr
# Out:
# ([40.899,
#   40.898,
#   40.897000000000006,
#   40.89600000000001,
#   40.89500000000001,
#   40.89400000000001,
#   40.893000000000015,
#   40.89200000000002,
#   40.89100000000002,
#   40.89000000000002,
#   40.889000000000024,
#   40.88800000000003,
#   40.88700000000003,
#   40.88600000000003,
#   40.88500000000003,
#   40.884000000000036,
#   40.88300000000004,
#   40.88200000000004,
#   40.88100000000004,
#   40.880000000000045,
#   40.87900000000005,
#   40.87800000000005,
#   40.87700000000005,
#   40.876000000000055,
#   40.87500000000006,
#   40.87400000000006,
#   40.87300000000006,
#   40.872000000000064,
#   40.871000000000066,
#   40.87000000000007,
#   40.86900000000007,
#   40.86800000000007,
#   40.867000000000075,
#   40.86600000000008,
#   40.86500000000008,
#   40.86400000000008,
#   40.863000000000085,
#   40.86200000000009,
#   40.86100000000009,
#   40.86000000000009,
#   40.859000000000094,
#   40.8580000000001,
#   40.8570000000001,
#   40.8560000000001,
# ...

# %%
len(x_arr)
# Out:
# 400

# %%
all_points = []
for i in x_arr:
    for j in y_arr:
        all_points.append([i,j])
        
all_points
# Out:
# [[40.899, -74.199],
#  [40.899, -74.198],
#  [40.899, -74.19699999999999],
#  [40.899, -74.19599999999998],
#  [40.899, -74.19499999999998],
#  [40.899, -74.19399999999997],
#  [40.899, -74.19299999999997],
#  [40.899, -74.19199999999996],
#  [40.899, -74.19099999999996],
#  [40.899, -74.18999999999996],
#  [40.899, -74.18899999999995],
#  [40.899, -74.18799999999995],
#  [40.899, -74.18699999999994],
#  [40.899, -74.18599999999994],
#  [40.899, -74.18499999999993],
#  [40.899, -74.18399999999993],
#  [40.899, -74.18299999999992],
#  [40.899, -74.18199999999992],
#  [40.899, -74.18099999999991],
#  [40.899, -74.17999999999991],
#  [40.899, -74.1789999999999],
#  [40.899, -74.1779999999999],
#  [40.899, -74.1769999999999],
#  [40.899, -74.17599999999989],
#  [40.899, -74.17499999999988],
#  [40.899, -74.17399999999988],
#  [40.899, -74.17299999999987],
#  [40.899, -74.17199999999987],
#  [40.899, -74.17099999999986],
#  [40.899, -74.16999999999986],
#  [40.899, -74.16899999999985],
# ...

# %%
len(all_points)
# Out:
# 160000

# %%
datafra =  pd.DataFrame(all_points)

# %%
datafra
# Out:
#              0       1
# 0       40.899 -74.199
# 1       40.899 -74.198
# 2       40.899 -74.197
# 3       40.899 -74.196
# 4       40.899 -74.195
# ...        ...     ...
# 159995  40.500 -73.804
# 159996  40.500 -73.803
# 159997  40.500 -73.802
# 159998  40.500 -73.801
# 159999  40.500 -73.800
#
# [160000 rows x 2 columns]

# %%
datafra["2"] = dataf1["x2"]

# %%
datafra["3"] = dataf1["y2"]
datafra
# Out:
#              0       1          2          3
# 0       40.899 -74.199  40.851488 -73.935458
# 1       40.899 -74.198  40.800694 -73.941109
# 2       40.899 -74.197  40.736698 -73.983316
# 3       40.899 -74.196  40.828851 -73.943834
# 4       40.899 -74.195  40.783862 -73.975956
# ...        ...     ...        ...        ...
# 159995  40.500 -73.804        NaN        NaN
# 159996  40.500 -73.803        NaN        NaN
# 159997  40.500 -73.802        NaN        NaN
# 159998  40.500 -73.801        NaN        NaN
# 159999  40.500 -73.800        NaN        NaN
#
# [160000 rows x 4 columns]

# %%
npx1 = dataf1["x2"].to_numpy()
npx2 = dataf2["x2"].to_numpy()
npx3 = dataf3["x2"].to_numpy()
print(npx1, npx2, npx3)
# Out:
# [40.85148777 40.80069433 40.73669807 40.82885105 40.78386245 40.81573205
#  40.75410547] [40.73917942 40.8335397 ] [40.8087499  40.82196725 40.81286174]

# %%
# Out:
# array([40.85148777, 40.80069433, 40.73669807, 40.82885105, 40.78386245,
#        40.81573205, 40.75410547, 40.73917942, 40.8335397 , 40.8087499 ,
#        40.82196725, 40.81286174])

# %%
npy1 = dataf1["y2"].to_numpy()
npy2 = dataf2["y2"].to_numpy()
npy3 = dataf3["y2"].to_numpy()
print(npy1, npy2, npy3)
# Out:
# [-73.93545797 -73.94110929 -73.98331603 -73.94383419 -73.97595583
#  -73.94542041 -73.97055611] [-73.9839469 -73.9397576] [-73.95258581 -73.9564243  -73.96051246]

# %%
# Out:
# array([-73.93545797, -73.94110929, -73.98331603, -73.94383419,
#        -73.97595583, -73.94542041, -73.97055611, -73.9839469 ,
#        -73.9397576 , -73.95258581, -73.9564243 , -73.96051246])

# %%
some_points_1 = []
some_points_2 = []
some_points_3 = []

some_points_1 = np.stack((npx1, npy1), axis=1)
some_points_2 = np.stack((npx2, npy2), axis=1)
some_points_3 = np.stack((npx3, npy3), axis=1)

print(some_points_1, some_points_2, some_points_3)
# Out:
# [[ 40.85148777 -73.93545797]
#  [ 40.80069433 -73.94110929]
#  [ 40.73669807 -73.98331603]
#  [ 40.82885105 -73.94383419]
#  [ 40.78386245 -73.97595583]
#  [ 40.81573205 -73.94542041]
#  [ 40.75410547 -73.97055611]] [[ 40.73917942 -73.9839469 ]
#  [ 40.8335397  -73.9397576 ]] [[ 40.8087499  -73.95258581]
#  [ 40.82196725 -73.9564243 ]
#  [ 40.81286174 -73.96051246]]

# %%
distance_m1 = []
distance_m2 = []
distance_m3 = []


for i in all_points:
    for j in some_points_1:
        distance_m1.append(math.hypot(j[0]-i[0] , j[1]-i[1]))
        
for i in all_points:
    for j in some_points_2:
        distance_m2.append(math.hypot(j[0]-i[0] , j[1]-i[1]))
        
for i in all_points:
    for j in some_points_3:
        distance_m3.append(math.hypot(j[0]-i[0] , j[1]-i[1]))
        
#print(distance_m1, distance_m2, distance_m3)

# %%
print(len(distance_m1), len(distance_m2), len(distance_m3))
# Out:
# 1120000 320000 480000

# %%
d_div_r1 = []
d_div_r2 = []
d_div_r3 = []

for d in distance_m1:
    d_div_r1.append(d/search_radius1)
for d in distance_m2:
    d_div_r2.append(d/search_radius2)
for d in distance_m3:
    d_div_r3.append(d/search_radius3)

#print(d_div_r1, d_div_r2, d_div_r3)

# %%
print(len(d_div_r1), len(d_div_r2), len(d_div_r3))
# Out:
# 1120000 320000 480000

# %%
sq_dr1 = []
sq_dr2 = []
sq_dr3 = []

for dr in d_div_r1:
    sq_dr1.append(math.pow((1 - math.pow(dr,2)), 2))
    
for dr in d_div_r2:
    sq_dr2.append(math.pow((1 - math.pow(dr,2)), 2))
    
for dr in d_div_r3:
    sq_dr3.append(math.pow((1 - math.pow(dr,2)), 2))

# %%
print(len(sq_dr1), len(sq_dr2), len(sq_dr3))
# Out:
# 1120000 320000 480000

# %%
# m1_sq_dr = []
# for dr in sq_dr:
#     m1_sq_dr.append(1 - dr) 
# m1_sq_dr
# Out:
# [-205.00808796834477,
#  -217.81988145150436,
#  -208.3107939219511,
#  -200.17804072964395,
#  -179.9968510361731,
#  -203.6416611559527,
#  -209.22875499497312,
#  -205.23399294956764,
#  -204.37567731853096,
#  -196.83008138643885,
#  -185.08633745109265,
#  -183.70481458128526,
#  -203.49679484482786,
#  -216.3410576616759,
#  -207.07446656967116,
#  -198.71487272737812,
#  -178.71823611703348,
#  -202.18760669098396,
#  -207.91911626698825,
#  -204.0012902769012,
#  -202.8890875047288,
#  -195.4171952931831,
#  -183.69550520801744,
#  -182.33747065899965,
#  -201.99124716475313,
#  -214.86797931528946,
#  -205.8438846608334,
#  -197.2574501685545,
#  -177.44536664133605,
#  -200.7392976694574,
#  -206.6152229824457,
#  -202.7743330476769,
#  -201.40824313436892,
#  -194.01005464336959,
#  -182.31041840838424,
#  -180.97587218015622,
#  -200.4914449281206,
#  -213.4006464123453,
#  -204.6190481954378,
#  -195.80577305317306,
#  -176.17824260908074,
#  -199.29673409137303,
# ...

# %%
# len(m1_sq_dr)
# Out:
# 1920000

# %%
# sqm1_sq_dr = []
# for dr in m1_sq_dr:
#     sqm1_sq_dr.append(math.pow(dr , 2)) 
# sqm1_sq_dr
# Out:
# [42028.31613243659,
#  47445.500755547415,
#  43393.38686439358,
#  40071.24799035899,
#  32398.86638293829,
#  41469.926158355855,
#  43776.67191674649,
#  42120.99186202318,
#  41769.417479408294,
#  38742.08093859214,
#  34256.952311059744,
#  33747.4589003444,
#  41410.945512117956,
#  46803.45323017258,
#  42879.834705113855,
#  39487.60064305808,
#  31940.20792078373,
#  40879.828299428016,
#  43230.35890924538,
#  41616.5264346405,
#  41163.9818285015,
#  38187.88021625407,
#  33744.03863362876,
#  33246.95320632156,
#  40800.46393117239,
#  46168.24853503566,
#  42371.70485226248,
#  38910.501646999764,
#  31486.858142478177,
#  40296.26562882702,
#  42689.850368085754,
#  41117.430142930185,
#  40565.280402473065,
#  37639.90130272325,
#  33237.08866024013,
#  32752.26631136824,
#  40196.81948936561,
#  45539.83588920683,
#  41868.9548844069,
#  38339.90076095071,
#  31038.77316882411,
#  39719.18821948745,
#  42155.101344596864,
#  40623.660690412056,
#  39973.26215267744,
# ...

# %%
# len(sqm1_sq_dr)
# Out:
# 1920000

# %%
pi_sq_dr1 = []
pi_sq_dr2 = []
pi_sq_dr3 = []

for dr in sq_dr1:
    pi_sq_dr1.append( (3/math.pi)* dr)
    
for dr in sq_dr2:
    pi_sq_dr2.append( (3/math.pi)* dr)
    
for dr in sq_dr3:
    pi_sq_dr3.append( (3/math.pi)* dr)

# %%
print(len(pi_sq_dr1), len(pi_sq_dr2), len(pi_sq_dr3))
# Out:
# 1120000 320000 480000

# %%
su_pi_sq_dr1 = np.add.reduceat(pi_sq_dr1, np.arange(0, len(pi_sq_dr1), 7))
su_pi_sq_dr2 = np.add.reduceat(pi_sq_dr2, np.arange(0, len(pi_sq_dr2), 2))
su_pi_sq_dr3 = np.add.reduceat(pi_sq_dr3, np.arange(0, len(pi_sq_dr3), 3))

print(len(su_pi_sq_dr1), len(su_pi_sq_dr2), len(su_pi_sq_dr3))
# Out:
# 160000 160000 160000

# %%
supi_sq_dr1 = su_pi_sq_dr1.tolist()
supi_sq_dr2 = su_pi_sq_dr2.tolist()
supi_sq_dr3 = su_pi_sq_dr3.tolist()

print(len(supi_sq_dr1), len(supi_sq_dr3), len(supi_sq_dr3))
# Out:
# 160000 160000 160000

# %%
#print(len(supi_sq_dr1), len(supi_sq_dr3), len(supi_sq_dr3))
# Out:
# [459532.0311266294,
#  453201.60364867735,
#  446941.3239075924,
#  440750.64698487235,
#  434629.0302316239,
#  428575.9332685625,
#  422590.81798601185,
#  416673.1485439048,
#  410822.3913717825,
#  405038.01516879513,
#  399319.49090370146,
#  393666.29181486886,
#  388077.89341027354,
#  382553.7734675002,
#  377093.41203374247,
#  371696.29142580257,
#  366361.8962300912,
#  361089.71330262814,
#  355879.2317690416,
#  350729.9430245686,
#  345641.3407340547,
#  340612.92083195463,
#  335644.18152233085,
#  330734.6232788555,
#  325883.748844809,
#  321091.0632330803,
#  316356.07372616744,
#  311678.2898761768,
#  307057.22350482363,
#  302492.3887034319,
#  297983.30183293397,
#  293529.4815238714,
#  289130.44867639395,
#  284785.7264602606,
#  280494.84031483834,
#  276257.3179491035,
#  272072.68934164074,
#  267940.4867406434,
#  263860.24466391373,
#  259831.4998988625,
#  255853.7915025093,
#  251926.66080148227,
#  248049.65139201842,
#  244222.30913996327,
# ...

# %%
#len(supi_sq_dr1)
# Out:
# 160000

# %%
density1 = []
density2 = []
density3 = []

for dr in supi_sq_dr1:
    density1.append( (1/search_radius1**2) * dr) 
    
for dr in supi_sq_dr2:
    density2.append( (1/search_radius2**2) * dr) 
    
for dr in supi_sq_dr3:
    density3.append( (1/search_radius3**2) * dr) 
    
print(len(density1), len(density3), len(density3))
# Out:
# 160000 160000 160000

# %%
#len(density)
# Out:
# 160000

# %%
datafra
# Out:
#              0       1          2          3       density
# 0       40.899 -74.199  40.851488 -73.935458  1.320108e+09
# 1       40.899 -74.198  40.800694 -73.941109  1.301922e+09
# 2       40.899 -74.197  40.736698 -73.983316  1.283938e+09
# 3       40.899 -74.196  40.828851 -73.943834  1.266154e+09
# 4       40.899 -74.195  40.783862 -73.975956  1.248568e+09
# ...        ...     ...        ...        ...           ...
# 159995  40.500 -73.804        NaN        NaN  3.612477e+09
# 159996  40.500 -73.803        NaN        NaN  3.631348e+09
# 159997  40.500 -73.802        NaN        NaN  3.650396e+09
# 159998  40.500 -73.801        NaN        NaN  3.669622e+09
# 159999  40.500 -73.800        NaN        NaN  3.689027e+09
#
# [160000 rows x 5 columns]

# %%
datafra["density"] = density

# %%
datafra
# Out:
#              0       1          2          3       density
# 0       40.899 -74.199  40.851488 -73.935458  1.320108e+09
# 1       40.899 -74.198  40.800694 -73.941109  1.301922e+09
# 2       40.899 -74.197  40.736698 -73.983316  1.283938e+09
# 3       40.899 -74.196  40.828851 -73.943834  1.266154e+09
# 4       40.899 -74.195  40.783862 -73.975956  1.248568e+09
# ...        ...     ...        ...        ...           ...
# 159995  40.500 -73.804        NaN        NaN  3.612477e+09
# 159996  40.500 -73.803        NaN        NaN  3.631348e+09
# 159997  40.500 -73.802        NaN        NaN  3.650396e+09
# 159998  40.500 -73.801        NaN        NaN  3.669622e+09
# 159999  40.500 -73.800        NaN        NaN  3.689027e+09
#
# [160000 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = [10, 30]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax1 = fig.add_subplot(311, projection='3d')
ax2 = fig.add_subplot(312, projection='3d')
ax3 = fig.add_subplot(313, projection='3d')

x_cord = np.array(x_arr)
y_cord = np.array(np.flip(y_arr))

npdensity1 = np.array(density1)
npdensity2 = np.array(density2)
npdensity3 = np.array(density3)

X, Y = np.meshgrid(y_cord, x_cord)

Z1 = npdensity1.reshape((len(x_arr), len(y_arr)))
Z2 = npdensity2.reshape((len(x_arr), len(y_arr)))
Z3 = npdensity3.reshape((len(x_arr), len(y_arr)))

ax1.plot_surface(X, Y, Z1, rstride=1, cstride=1, cmap="plasma", linewidth=0, antialiased=False)
ax2.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax3.plot_surface(X, Y, Z3, rstride=1, cstride=1, cmap="magma", linewidth=0, antialiased=False)

ax1.invert_xaxis()
ax2.invert_xaxis()
ax3.invert_xaxis()

ax1.invert_zaxis()
ax2.invert_zaxis()
ax3.invert_zaxis()

plt.show()

# %%
print(Z1.min(), Z2.min(), Z3.min())
# Out:
# 78409.62264588066 454.29958727738455 155005.6083241894

# %%
print(Z1.max(), Z2.max(), Z3.max())
# Out:
# 549661432.4999897 8592295.320718763 7289368273129.099

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = [10, 30]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax1 = fig.add_subplot(311, projection='3d')
ax2 = fig.add_subplot(312, projection='3d')
ax3 = fig.add_subplot(313, projection='3d')

x_cord = np.array(x_arr)
y_cord = np.array(np.flip(y_arr))

npdensity1 = np.array(density1)
npdensity2 = np.array(density2)
npdensity3 = np.array(density3)

X, Y = np.meshgrid(y_cord, x_cord)

Z1 = npdensity1.reshape((len(x_arr), len(y_arr)))
Z2 = npdensity2.reshape((len(x_arr), len(y_arr)))
Z3 = npdensity3.reshape((len(x_arr), len(y_arr)))

ax1.plot_surface(X, Y, Z1, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax1.contour(X, Y, Z1, 10, cmap="autumn_r", linestyles="solid", offset=-1)
#ax1.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax2.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax2.contour(X, Y, Z2, 10, cmap="autumn_r", linestyles="solid", offset=-1)
#ax2.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax3.plot_surface(X, Y, Z3, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax3.contour(X, Y, Z3, 10, cmap="autumn_r", linestyles="solid", offset=-1)
#ax3.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax1.invert_xaxis()
ax2.invert_xaxis()
ax3.invert_xaxis()

ax1.invert_zaxis()
ax2.invert_zaxis()
ax3.invert_zaxis()

plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 30]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax1 = fig.add_subplot(311, projection='3d')
ax2 = fig.add_subplot(312, projection='3d')
ax3 = fig.add_subplot(313, projection='3d')


ax1.plot_surface(X, Y, Z1, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax1.contourf(X, Y, Z1, 10, cmap="autumn_r", linestyles="solid", offset = 549661433)
#ax1.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax2.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax2.contourf(X, Y, Z2, 10, cmap="autumn_r", linestyles="solid", offset = 8592296)
#ax2.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax3.plot_surface(X, Y, Z3, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax3.contourf(X, Y, Z3, 10, cmap="autumn_r", linestyles="solid", offset = 7289368273130)
#ax3.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax1.invert_xaxis()
ax2.invert_xaxis()
ax3.invert_xaxis()

ax1.invert_zaxis()
ax2.invert_zaxis()
ax3.invert_zaxis()

ax1.auto_scale_xyz([-73.80,-74.20] ,[40.9,40.5], [0, 1200000000])
ax2.auto_scale_xyz([-73.80,-74.20] ,[40.9,40.5], [0, 18000000])
ax3.auto_scale_xyz([-73.80,-74.20] ,[40.9,40.5], [0, 14000000000000])

plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 30]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax1 = fig.add_subplot(311, projection='3d')
ax2 = fig.add_subplot(312, projection='3d')
ax3 = fig.add_subplot(313, projection='3d')


ax1.plot_surface(X, Y, Z1, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax1.contourf(X, Y, Z1, 10, cmap="autumn_r", linestyles="solid", offset = 1200000000)
#ax1.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax2.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax2.contourf(X, Y, Z2, 10, cmap="autumn_r", linestyles="solid", offset = 18000000)
#ax2.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax3.plot_surface(X, Y, Z3, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax3.contourf(X, Y, Z3, 10, cmap="autumn_r", linestyles="solid", offset = 14000000000000)
#ax3.contour(X, Y, Z, 10, lw=3, colors="k", linestyles="solid")

ax1.invert_xaxis()
ax2.invert_xaxis()
ax3.invert_xaxis()

ax1.invert_zaxis()
ax2.invert_zaxis()
ax3.invert_zaxis()

ax1.auto_scale_xyz([-73.80,-74.20] ,[40.9,40.5], [0, 1200000000])
ax2.auto_scale_xyz([-73.80,-74.20] ,[40.9,40.5], [0, 18000000])
ax3.auto_scale_xyz([-73.80,-74.20] ,[40.9,40.5], [0, 14000000000000])

plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax4 = fig.add_subplot(111, projection='3d')
#x_cord = np.array(x_arr)
#y_cord = np.array(np.flip(y_arr))
#y_cord_rev = np.flip(y_arr)
#X, Y = np.meshgrid(x_cord, y_cord)
#Z2 = np.array(np.flip(Z))
#Z2 = Z.reshape((len(x_arr), len(y_arr)))

ax4.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax4 = plt.gca()
ax4.invert_xaxis()
ax4.invert_zaxis()
ax4.auto_scale_xyz([-73.80,-74.20] ,[40.9,40.5], [0, 1200000000])

plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax4 = fig.add_subplot(111, projection='3d')
#x_cord = np.array(x_arr)
#y_cord = np.array(np.flip(y_arr))
#y_cord_rev = np.flip(y_arr)
#X, Y = np.meshgrid(x_cord, y_cord)
#Z2 = np.array(np.flip(Z))
#Z2 = Z.reshape((len(x_arr), len(y_arr)))

ax4.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="viridis", linewidth=0, antialiased=False)
ax4 = plt.gca()
ax4.invert_xaxis()
ax4.invert_zaxis()
ax4.auto_scale_xyz([-73.80,-74.20] ,[40.9,40.5], [0, 1200000000])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
x_cord = np.array(x_arr)
y_cord = np.array(np.flip(y_arr))
#y_cord_rev = np.flip(y_arr)
Z = datafra["density"].to_numpy()
X, Y = np.meshgrid(y_cord, x_cord)
Z2 = np.array(Z)
Z2 = Z.reshape((len(x_arr), len(y_arr)))

ax.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="plasma", linewidth=0, antialiased=False)
ax = plt.gca()
ax.invert_xaxis()

plt.show()

# %%
#import matplotlib.pyplot as plt
#import numpy as np

plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax1 = fig.add_subplot(111, projection='3d')
#x_cord = np.array(x_arr)
#y_cord = np.array(np.flip(y_arr))

#X, Y = np.meshgrid(x_cord, y_cord)
#Z2 = np.array(Z)
#Z2 = Z.reshape((len(x_arr), len(y_arr)))

ax1.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="plasma", linewidth=0, antialiased=False)
ax1 = plt.gca()
ax1.invert_xaxis()

plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax2 = fig.add_subplot(111, projection='3d')
#x_cord = np.array(x_arr)
#y_cord = np.array(np.flip(y_arr))
#y_cord_rev = np.flip(y_arr)
#X, Y = np.meshgrid(x_cord, y_cord)
#Z2 = np.array(np.flip(Z))
#Z2 = Z.reshape((len(x_arr), len(y_arr)))

ax2.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="plasma", linewidth=0, antialiased=False)
ax2 = plt.gca()
ax2.invert_xaxis()
ax2.invert_zaxis()

plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax3 = fig.add_subplot(111, projection='3d')
x_cord = np.array(x_arr)
y_cord = np.array(np.flip(y_arr))
y_cord_rev = np.flip(y_arr)
X, Y = np.meshgrid(x_cord, y_cord)
Z2 = np.array(np.flip(Z))
Z2 = Z.reshape((len(x_arr), len(y_arr)))

ax3.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="plasma", linewidth=0, antialiased=False)
ax3 = plt.gca()
ax3.invert_xaxis()
ax3.invert_zaxis()
#ax3.auto_scale_xyz([40.9, 40.5], [-73.8, -74.2], [0, 100000000])

plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()

ax4 = fig.add_subplot(111, projection='3d')
#x_cord = np.array(x_arr)
#y_cord = np.array(np.flip(y_arr))
#y_cord_rev = np.flip(y_arr)
#X, Y = np.meshgrid(x_cord, y_cord)
#Z2 = np.array(np.flip(Z))
#Z2 = Z.reshape((len(x_arr), len(y_arr)))

ax4.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap="plasma", linewidth=0, antialiased=False)
ax4 = plt.gca()
ax4.invert_xaxis()
ax4.invert_zaxis()
ax4.auto_scale_xyz([40.86, 40.72], [-73.94, -74.01], [0, 120000000])

plt.show()

# %%
Z = datafra["density"].to_numpy()

# %%
min(density)
# Out:
# 3071166.5374983996

# %%
max(density)
# Out:
# 66264682.21175884

# %%
datafra
# Out:
#                 0          1          2          3       density
# 0       40.861278 -74.006892  40.851488 -73.935458  5.015539e+07
# 1       40.861278 -74.006695  40.800694 -73.941109  5.004255e+07
# 2       40.861278 -74.006497  40.736698 -73.983316  4.993075e+07
# 3       40.861278 -74.006299  40.828851 -73.943834  4.981999e+07
# 4       40.861278 -74.006101  40.783862 -73.975956  4.971026e+07
# ...           ...        ...        ...        ...           ...
# 159995  40.717283 -73.928756        NaN        NaN  4.068771e+07
# 159996  40.717283 -73.928558        NaN        NaN  4.077330e+07
# 159997  40.717283 -73.928360        NaN        NaN  4.085981e+07
# 159998  40.717283 -73.928162        NaN        NaN  4.094722e+07
# 159999  40.717283 -73.927965        NaN        NaN  4.103554e+07
#
# [160000 rows x 5 columns]

# %%
#datafra.to_csv(index = False)

# %%
#compression_opts = dict(method='zip', archive_name='output.csv') 
#datafra.to_csv('output.zip', index=False,compression=compression_opts)

# %%
Z2 = np.array(Z)
Z2 = Z.reshape((len(x_arr), len(y_arr)))

# %%
Z2
# Out:
# array([[50155389.63068145, 50042549.36502752, 49930750.49923573, ...,
#         65890506.37963008, 66077119.01335882, 66264682.21175884],
#        [49565236.96112859, 49453045.05092321, 49341890.38115796, ...,
#         65230795.29399811, 65416404.99262412, 65602961.09649936],
#        [48980990.16085828, 48869442.28746057, 48758927.51550703, ...,
#         64576881.19019821, 64761491.74423704, 64947044.56452915],
#        ...,
#        [60285289.51031461, 60090375.27155412, 59896456.75508928, ...,
#         39846508.14040461, 39932912.80710982, 40020222.36091976],
#        [60902014.89470614, 60706034.51095895, 60511053.79924181, ...,
#         40350446.7908612 , 40437353.35715441, 40525168.76028679],
#        [61524271.02149221, 61327220.17411739, 61131172.96893317, ...,
#         40859807.29626179, 40947219.55265858, 41035544.61605511]])

# %%
Z2 = np.array(Z)
Z2 = Z.reshape((len(x_arr), len(y_arr)))

# %%
test = plt.contourf(Y, X, Z2)
plt.show()

# %%
plt.contourf(Y,X, Z2, 8, alpha =.75, cmap =plt.cm.hot)
#C = plt.contour(Y,X, Z2, 8, colors ='black', linewidth=.5)
plt.show()
